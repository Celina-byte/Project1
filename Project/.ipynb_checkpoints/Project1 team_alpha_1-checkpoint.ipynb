# %%
import pandas as pd
# !pip install openpyxl
import matplotlib.pyplot as plt
import os
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
try:
    os.mkdir("Results")
except OSError as error:
    print(error)

# %%
# Load file
datafile20 = "Resources/2020.csv"
datafile19 = "Resources/2019.csv"
datafile18 = "Resources/2018.csv"
datafile17 = "Resources/2017.csv"
datafile16 = "Resources/2016.csv"
datafile15 = "Resources/2015.csv"

# Read 202 File and store into Pandas data frame
yr20df = pd.read_csv(datafile20)
yr19df = pd.read_csv(datafile19)
yr18df = pd.read_csv(datafile18)

yr17df = pd.read_csv(datafile17)
yr16df = pd.read_csv(datafile16)
yr15df = pd.read_csv(datafile15)

# %%
cleanedyr20df = yr20df[["Country name","Ladder score","Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Explained by: Generosity","Explained by: Perceptions of corruption"]]
cleanedyr20df = cleanedyr20df.rename(columns={"Country name":"Country",
                      "Ladder score":"Score 20",
                      "Explained by: Log GDP per capita":"GDP per capita 20",
                      "Explained by: Social support":"Social Support 20",
                    "Explained by: Healthy life expectancy":"Healthy life expectancy 20",
                    "Explained by: Freedom to make life choices":"Freedom to make life choices 20",
                    "Explained by: Generosity":"Generosity 20",
                    "Explained by: Perceptions of corruption":"Perceptions of corruption 20"
                     })
cleanedyr20df.shape
# Out:
# (153, 8)

# %%
yr19df = yr19df.rename(columns={"Country or region":"Country"})

# %%
cleanedyr20and19df = pd.merge(cleanedyr20df,yr19df,how='left',on ='Country')
cleanedyr20and19df = cleanedyr20and19df.rename(columns={
                      "Score":"Score 19",
                      "GDP per capita":"GDP per capita 19",
                      "Social support":"Social Support 19",
                    "Healthy life expectancy":"Healthy life expectancy 19",
                    "Freedom to make life choices":"Freedom to make life choices 19",
                    "Generosity":"Generosity 19",
                    "Perceptions of corruption":"Perceptions of corruption 19"
                     })
cleanedyr20and19df
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
yr18df = yr18df.rename(columns={"Country or region":"Country"})

# %%
cleaned3yrsdf = pd.merge(cleanedyr20and19df,yr18df,how='left',on ='Country')
cleaned3yrsdf
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
cleaned3yrsdf = cleaned3yrsdf.rename(columns={
                      "Score":"Score 18",
                      "GDP per capita":"GDP per capita 18",
                      "Social support":"Social Support 18",
                    "Healthy life expectancy":"Healthy life expectancy 18",
                    "Freedom to make life choices":"Freedom to make life choices 18",
                    "Generosity":"Generosity 18",
                    "Perceptions of corruption":"Perceptions of corruption 18"
                     })
del cleaned3yrsdf["Overall rank_x"]
del cleaned3yrsdf["Overall rank_y"]

# %%
cleaned3yrsdf.tail(20)
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 133                   Comoros    4.2886           0.415621           0.723233
# 134                      Togo    4.1872           0.268116           0.547623
# 135                  Ethiopia    4.1862           0.315126           1.001103
# 136                Madagascar    4.1656           0.244553           0.823694
# 137                     Egypt    4.1514           0.875229           0.982540
# 138              Sierra Leone    3.9264           0.240560           0.747985
# 139                   Burundi    3.7753           0.000000           0.403575
# 140                    Zambia    3.7594           0.536834           0.896037
# 141                     Haiti    3.7208           0.284734           0.646671
# 142                   Lesotho    3.6528           0.454939           1.088940
# 143                     India    3.5733           0.730576           0.644199
# ...

# %%
cleanedyr17df = yr17df[["Country","Happiness.Score","Economy..GDP.per.Capita.","Family","Health..Life.Expectancy.",
                        "Freedom","Generosity","Trust..Government.Corruption."]]
cleanedyr17df = cleanedyr17df.rename(columns={"Happiness.Score":"Score 17",
                      "Economy..GDP.per.Capita.":"GDP per capita 17",
                      "Family":"Social Support 17",
                    "Health..Life.Expectancy.":"Healthy life expectancy 17",
                    "Freedom":"Freedom to make life choices 17",
                    "Generosity":"Generosity 17",
                    "Trust..Government.Corruption.":"Perceptions of corruption 17"
                     })
cleanedyr17df.shape

cleanedyr17df
# Out:
#                       Country  Score 17  GDP per capita 17  Social Support 17  \
# 0                      Norway     7.537           1.616463           1.533524
# 1                     Denmark     7.522           1.482383           1.551122
# 2                     Iceland     7.504           1.480633           1.610574
# 3                 Switzerland     7.494           1.564980           1.516912
# 4                     Finland     7.469           1.443572           1.540247
# ..                        ...       ...                ...                ...
# 150                    Rwanda     3.471           0.368746           0.945707
# 151                     Syria     3.462           0.777153           0.396103
# 152                  Tanzania     3.349           0.511136           1.041990
# 153                   Burundi     2.905           0.091623           0.629794
# 154  Central African Republic     2.693           0.000000           0.000000
#
# ...

# %%
cleanedyr16df = yr16df[["Country","Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)",
                        "Freedom","Generosity","Trust (Government Corruption)"]]
cleanedyr16df = cleanedyr16df.rename(columns={"Happiness Score":"Score 16",
                      "Economy (GDP per Capita)":"GDP per capita 16",
                      "Family":"Social Support 16",
                    "Health (Life Expectancy)":"Healthy life expectancy 16",
                    "Freedom":"Freedom to make life choices 16",
                    "Generosity":"Generosity 16",
                    "Trust (Government Corruption)":"Perceptions of corruption 16"
                     })
cleanedyr16df.shape

cleanedyr16df
# Out:
#          Country  Score 16  GDP per capita 16  Social Support 16  \
# 0        Denmark     7.526            1.44178            1.16374
# 1    Switzerland     7.509            1.52733            1.14524
# 2        Iceland     7.501            1.42666            1.18326
# 3         Norway     7.498            1.57744            1.12690
# 4        Finland     7.413            1.40598            1.13464
# ..           ...       ...                ...                ...
# 152        Benin     3.484            0.39499            0.10419
# 153  Afghanistan     3.360            0.38227            0.11037
# 154         Togo     3.303            0.28123            0.00000
# 155        Syria     3.069            0.74719            0.14866
# 156      Burundi     2.905            0.06831            0.23442
#
#      Healthy life expectancy 16  Freedom to make life choices 16  \
# 0                       0.79504                          0.57941
# ...

# %%
cleanedyr15df = yr15df[["Country","Happiness Score","Economy (GDP per Capita)","Family","Health (Life Expectancy)",
                        "Freedom","Generosity","Trust (Government Corruption)"]]
cleanedyr15df = cleanedyr15df.rename(columns={"Happiness Score":"Score 15",
                      "Economy (GDP per Capita)":"GDP per capita 15",
                      "Family":"Social Support 15",
                    "Health (Life Expectancy)":"Healthy life expectancy 15",
                    "Freedom":"Freedom to make life choices 15",
                    "Generosity":"Generosity 15",
                    "Trust (Government Corruption)":"Perceptions of corruption 15"
                     })
cleanedyr15df.shape

cleanedyr15df
# Out:
#          Country  Score 15  GDP per capita 15  Social Support 15  \
# 0    Switzerland     7.587            1.39651            1.34951
# 1        Iceland     7.561            1.30232            1.40223
# 2        Denmark     7.527            1.32548            1.36058
# 3         Norway     7.522            1.45900            1.33095
# 4         Canada     7.427            1.32629            1.32261
# ..           ...       ...                ...                ...
# 153       Rwanda     3.465            0.22208            0.77370
# 154        Benin     3.340            0.28665            0.35386
# 155        Syria     3.006            0.66320            0.47489
# 156      Burundi     2.905            0.01530            0.41587
# 157         Togo     2.839            0.20868            0.13995
#
#      Healthy life expectancy 15  Freedom to make life choices 15  \
# 0                       0.94143                          0.66557
# ...

# %%
cleaned4yrsdf = pd.merge(cleaned3yrsdf,cleanedyr17df,how='left',on ='Country')
cleaned4yrsdf
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
cleaned5yrsdf = pd.merge(cleaned4yrsdf,cleanedyr16df,how='left',on ='Country')
cleaned5yrsdf
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
cleaned6yrsdf = pd.merge(cleaned5yrsdf,cleanedyr15df,how='left',on ='Country')
cleaned6yrsdf
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
cleaned6yrsdf.dropna(inplace = True)
cleaned6yrsdf.count()
# Out:
# Country                            137
# Score 20                           137
# GDP per capita 20                  137
# Social Support 20                  137
# Healthy life expectancy 20         137
# Freedom to make life choices 20    137
# Generosity 20                      137
# Perceptions of corruption 20       137
# Score 19                           137
# GDP per capita 19                  137
# Social Support 19                  137
# Healthy life expectancy 19         137
# Freedom to make life choices 19    137
# Generosity 19                      137
# Perceptions of corruption 19       137
# Score 18                           137
# GDP per capita 18                  137
# Social Support 18                  137
# Healthy life expectancy 18         137
# Freedom to make life choices 18    137
# Generosity 18                      137
# Perceptions of corruption 18       137
# Score 17                           137
# GDP per capita 17                  137
# ...

# %%
cleaned6yrsdf
# Out:
#          Country  Score 20  GDP per capita 20  Social Support 20  \
# 0        Finland    7.8087           1.285190           1.499526
# 1        Denmark    7.6456           1.326949           1.503449
# 2    Switzerland    7.5599           1.390774           1.472403
# 3        Iceland    7.5045           1.326502           1.547567
# 4         Norway    7.4880           1.424207           1.495173
# ..           ...       ...                ...                ...
# 146     Botswana    3.4789           0.997549           1.085695
# 147     Tanzania    3.4762           0.457163           0.872675
# 149       Rwanda    3.3123           0.343243           0.522876
# 150     Zimbabwe    3.2992           0.425564           1.047835
# 152  Afghanistan    2.5669           0.300706           0.356434
#
#      Healthy life expectancy 20  Freedom to make life choices 20  \
# 0                      0.961271                         0.662317
# ...

# %%
cleaned6yrsdf.to_excel("2015-2020 happiness.xlsx")

# %%
mean20=cleaned6yrsdf["Score 20"].mean()
mean20
# Out:
# 5.541521161145985

# %%
cleaned6yrsdf['New Score']=cleaned6yrsdf["Score 20"]-mean20

# %%
cleaned6yrsdf.head()
# Out:
#        Country  Score 20  GDP per capita 20  Social Support 20  \
# 0      Finland    7.8087           1.285190           1.499526
# 1      Denmark    7.6456           1.326949           1.503449
# 2  Switzerland    7.5599           1.390774           1.472403
# 3      Iceland    7.5045           1.326502           1.547567
# 4       Norway    7.4880           1.424207           1.495173
#
#    Healthy life expectancy 20  Freedom to make life choices 20  Generosity 20  \
# 0                    0.961271                         0.662317       0.159670
# 1                    0.979333                         0.665040       0.242793
# 2                    1.040533                         0.628954       0.269056
# 3                    1.000843                         0.661981       0.362330
# 4                    1.008072                         0.670201       0.287985
#
#    Perceptions of corruption 20  Score 19  GDP per capita 19  ...  \
# ...

# %%
plt.figure(figsize=(30,7))
plt.plot(cleaned6yrsdf["Country"], cleaned6yrsdf["Score 20"])
# plt.plot(cleaned3yrsdf["GDP per capita 20"])
# plt.plot(cleaned3yrsdf["Social Support 20"])
# plt.plot(cleaned3yrsdf["Healthy life expectancy 20"])
# plt.plot(cleaned3yrsdf["Freedom to make life choices 20"])
# plt.plot(cleaned3yrsdf["Generosity 20"])
# plt.plot(cleaned3yrsdf["Perceptions of corruption 20"])
# plt.xticks(rotation='vertical')
plt.plot(cleaned6yrsdf["Country"], cleaned6yrsdf["GDP per capita 20"])

plt.title("Happiness Index 2020 vs. GDP per capita 2020")
plt.xticks(rotation='vertical')
plt.xlabel('Countries')
plt.ylabel('GDP')
plt.savefig('Results/One_plot_Happiness Index 2020 vs. GDP per capita 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(30,3))
plt.bar(cleaned6yrsdf["Country"],cleaned6yrsdf["GDP per capita 20"])
plt.xticks(rotation='vertical')
plt.title('GDP')
plt.xlabel('Countries')
plt.ylabel('GDP')
plt.savefig('Results/GDP.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(30,5))
plt.bar(cleaned6yrsdf["Country"], cleaned6yrsdf["New Score"])
plt.xticks(rotation='vertical')
plt.title('Happiest Countries')
plt.xlabel('Countries')
plt.ylabel('Happiness Score')
plt.savefig('Results/Happiest Countries.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(30,3))
plt.bar(cleaned6yrsdf["Country"],cleaned6yrsdf["GDP per capita 20"])
plt.xticks(rotation='vertical')
plt.title('GDP')
plt.xlabel('Countries')
plt.ylabel('GDP')
plt.savefig('Results/GDP.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
axs[0].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["GDP per capita 20"])
axs[1].set_title('GDP per capita 2020')
plt.xticks(rotation='vertical')
plt.savefig('Results/Happiness Index 2020 vs. GDP per capita 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.scatter(cleaned6yrsdf["GDP per capita 20"], cleaned6yrsdf["Score 20"], color="red")
plt.title("GDP per capita vs. Happiness index 2020")
plt.xlabel('GDP per capita 20')
plt.ylabel('Happiest Index 20')
plt.savefig('Results/GDP per capita vs. Happiness index 2020.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["Social Support 20"])
axs[1].set_title('Social Support 2020')
plt.xticks(rotation='vertical')
plt.savefig('Results/Happiness index 2020 vs. Social Support 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.scatter(cleaned6yrsdf["Social Support 20"], cleaned6yrsdf["Score 20"], color="red")
plt.title("Social Support vs. Happiness index 2020")
plt.xlabel('Social Support 20')
plt.ylabel('Happiest Index 20')
plt.savefig('Results/scatter_Social Support vs. Happiness index 2020.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["Healthy life expectancy 20"])
axs[1].set_title('Healthy Life Expectancy 2020')
plt.xticks(rotation='vertical')
plt.savefig('Results/Happiness Index 2020 vs. Healthy life expectancy 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.scatter(cleaned6yrsdf["Healthy life expectancy 20"], cleaned6yrsdf["Score 20"], color="red")
plt.title("Healthy Life Expectancy vs. Happiness index 2020")
plt.xlabel('Healthy Life Expectancy 20')
plt.ylabel('Happiest Index 20')
plt.savefig('Results/scatter_Healthy Life Expectancy vs. Happiness index 2020.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
axs[0].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["Freedom to make life choices 20"])
axs[1].set_title('Freedom To Make Life Choices 2020')
plt.xticks(rotation='vertical')
plt.savefig('Results/Happiness Index 2020 vs. Freedom To Make Life Choices 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.scatter(cleaned6yrsdf["Freedom to make life choices 20"], cleaned6yrsdf["Score 20"], color="red")
plt.title("Freedom To Make Life Choices vs. Happiness index 2020")
plt.xlabel('Freedom To Make Life Choices 20')
plt.ylabel('Happiest Index 20')
plt.savefig('Results/scatter_Freedom To Make Life Choices vs. Happiness index 2020.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
axs[0].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["Generosity 20"])
axs[1].set_title('Generosity 2020')
plt.xticks(rotation='vertical')
plt.savefig('Results/Happiness Index 2020 vs. Generosity 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.scatter(cleaned6yrsdf["Generosity 20"], cleaned6yrsdf["Score 20"], color="red")
plt.title("Generosity vs. Happiness index 2020")
plt.xlabel('Generosity 20')
plt.ylabel('Happiest Index 20')
plt.savefig('Results/scatter_Generosity vs. Happiness index 2020.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned6yrsdf["Country"],cleaned6yrsdf["Perceptions of corruption 20"])
axs[1].set_title('Perceptions of corruption 2020')
plt.xticks(rotation='vertical')
plt.savefig('Results/Happiness Index 2020 vs Perceptions of corruption 2020.png', bbox_inches='tight')
plt.show()

# %%
plt.scatter(cleaned6yrsdf["Perceptions of corruption 20"], cleaned6yrsdf["Score 20"], color="red")
plt.title("Perceptions of Corruption vs. Happiness index 2020")
plt.xlabel('Perceptions of Corruption 20')
plt.ylabel('Happiest Index 20')
plt.savefig('Results/scatter_Perceptions of Corruption vs. Happiness index 2020.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))


axs[0,0].scatter(cleaned6yrsdf["Social Support 20"], cleaned6yrsdf["Score 20"])
axs[0,0].set_title('Social Support 2020')
axs[0,1].scatter(cleaned6yrsdf["Social Support 19"], cleaned6yrsdf["Score 19"])
axs[0,1].set_title('Social Support 2019')
axs[1,0].scatter(cleaned6yrsdf["Social Support 18"], cleaned6yrsdf["Score 18"])
axs[1,0].set_title('Social Support 2018')

axs[1,1].scatter(cleaned6yrsdf["Social Support 17"], cleaned6yrsdf["Score 17"])
axs[1,1].set_title('Social Support 2017')
axs[2,0].scatter(cleaned6yrsdf["Social Support 16"], cleaned6yrsdf["Score 16"])
axs[2,0].set_title('Social Support 2016')
axs[2,1].scatter(cleaned6yrsdf["Social Support 15"], cleaned6yrsdf["Score 15"])
axs[2,1].set_title('Social Support 2015')

plt.savefig('Results/scatter_Social Support 2020 to 15.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

axs[0,0].scatter(cleaned6yrsdf["GDP per capita 20"], cleaned6yrsdf["Score 20"])
axs[0,0].set_title('GDP per capita 2020')
axs[0,1].scatter(cleaned6yrsdf["GDP per capita 19"], cleaned6yrsdf["Score 19"])
axs[0,1].set_title('GDP per capita 2019')
axs[1,0].scatter(cleaned6yrsdf["GDP per capita 18"], cleaned6yrsdf["Score 18"])
axs[1,0].set_title('GDP per capita 2018')

axs[1,1].scatter(cleaned6yrsdf["GDP per capita 17"], cleaned6yrsdf["Score 17"])
axs[1,1].set_title('GDP per capita 2017')
axs[2,0].scatter(cleaned6yrsdf["GDP per capita 16"], cleaned6yrsdf["Score 16"])
axs[2,0].set_title('GDP per capita 2016')
axs[2,1].scatter(cleaned6yrsdf["GDP per capita 15"], cleaned6yrsdf["Score 15"])
axs[2,1].set_title('GDP per capita 2015')

plt.savefig('Results/scatter_GDP per capita 2020 to 15.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

axs[0,0].scatter(cleaned6yrsdf["Healthy life expectancy 20"], cleaned6yrsdf["Score 20"])
axs[0,0].set_title('Healthy life expectancy 2020')
axs[0,1].scatter(cleaned6yrsdf["Healthy life expectancy 19"], cleaned6yrsdf["Score 19"])
axs[0,1].set_title('Healthy life expectancy 2019')
axs[1,0].scatter(cleaned6yrsdf["Healthy life expectancy 18"], cleaned6yrsdf["Score 18"])
axs[1,0].set_title('Healthy life expectancy 2018')

axs[1,1].scatter(cleaned6yrsdf["Healthy life expectancy 17"], cleaned6yrsdf["Score 17"])
axs[1,1].set_title('Healthy life expectancy 2017')
axs[2,0].scatter(cleaned6yrsdf["Healthy life expectancy 16"], cleaned6yrsdf["Score 16"])
axs[2,0].set_title('Healthy life expectancy 2016')
axs[2,1].scatter(cleaned6yrsdf["Healthy life expectancy 15"], cleaned6yrsdf["Score 15"])
axs[2,1].set_title('Healthy life expectancy 2015')

plt.savefig('Results/scatter_Healthy life expectancy 2020 to 15.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

axs[0,0].scatter(cleaned6yrsdf["Freedom to make life choices 20"], cleaned6yrsdf["Score 20"])
axs[0,0].set_title('Freedom to make life choices 2020')
axs[0,1].scatter(cleaned6yrsdf["Freedom to make life choices 19"], cleaned6yrsdf["Score 19"])
axs[0,1].set_title('Freedom to make life choices 2019')
axs[1,0].scatter(cleaned6yrsdf["Freedom to make life choices 18"], cleaned6yrsdf["Score 18"])
axs[1,0].set_title('Freedom to make life choices 2018')

axs[1,1].scatter(cleaned6yrsdf["Freedom to make life choices 17"], cleaned6yrsdf["Score 17"])
axs[1,1].set_title('Freedom to make life choices 2017')
axs[2,0].scatter(cleaned6yrsdf["Freedom to make life choices 16"], cleaned6yrsdf["Score 16"])
axs[2,0].set_title('Freedom to make life choices 2016')
axs[2,1].scatter(cleaned6yrsdf["Freedom to make life choices 15"], cleaned6yrsdf["Score 15"])
axs[2,1].set_title('Freedom to make life choices 2015')

plt.savefig('Results/scatter_Freedom to make life choices 2020 to 15.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

axs[0,0].scatter(cleaned6yrsdf["Generosity 20"], cleaned6yrsdf["Score 20"])
axs[0,0].set_title('Generosity 2020')
axs[0,1].scatter(cleaned6yrsdf["Generosity 19"], cleaned6yrsdf["Score 19"])
axs[0,1].set_title('Generosity 2019')
axs[1,0].scatter(cleaned6yrsdf["Generosity 18"], cleaned6yrsdf["Score 18"])
axs[1,0].set_title('Generosity 2018')

axs[1,1].scatter(cleaned6yrsdf["Generosity 17"], cleaned6yrsdf["Score 17"])
axs[1,1].set_title('Generosity 2017')
axs[2,0].scatter(cleaned6yrsdf["Generosity 16"], cleaned6yrsdf["Score 16"])
axs[2,0].set_title('Generosity 2016')
axs[2,1].scatter(cleaned6yrsdf["Generosity 15"], cleaned6yrsdf["Score 15"])
axs[2,1].set_title('Generosity 2015')

plt.savefig('Results/scatter_Generosity 2020 to 15.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

axs[0,0].scatter(cleaned6yrsdf["Perceptions of corruption 20"], cleaned6yrsdf["Score 20"])
axs[0,0].set_title('Perceptions of corruption 2020')
axs[0,1].scatter(cleaned6yrsdf["Perceptions of corruption 19"], cleaned6yrsdf["Score 19"])
axs[0,1].set_title('Perceptions of corruption 2019')
axs[1,0].scatter(cleaned6yrsdf["Perceptions of corruption 18"], cleaned6yrsdf["Score 18"])
axs[1,0].set_title('Perceptions of corruption 2018')

axs[1,1].scatter(cleaned6yrsdf["Perceptions of corruption 17"], cleaned6yrsdf["Score 17"])
axs[1,1].set_title('Perceptions of corruption 2017')
axs[2,0].scatter(cleaned6yrsdf["Perceptions of corruption 16"], cleaned6yrsdf["Score 16"])
axs[2,0].set_title('Perceptions of corruption 2016')
axs[2,1].scatter(cleaned6yrsdf["Perceptions of corruption 15"], cleaned6yrsdf["Score 15"])
axs[2,1].set_title('Perceptions of corruption 2015')

plt.savefig('Results/scatter_Perceptions of corruption 2020 to 15.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(1,6,sharey=True,figsize=(20,5))
fig.suptitle('Box plots for each variable')
axs[0].boxplot(cleaned6yrsdf["GDP per capita 20"])
axs[0].set_title("GDP per capita 20")
axs[1].boxplot(cleaned6yrsdf["Social Support 20"])
axs[1].set_title("Social Support 20")
axs[2].boxplot(cleaned6yrsdf["Healthy life expectancy 20"])
axs[2].set_title("Healthy life expectancy 20")
axs[3].boxplot(cleaned6yrsdf["Freedom to make life choices 20"])
axs[3].set_title("Freedom to make life choices 20")
axs[4].boxplot(cleaned6yrsdf["Generosity 20"])
axs[4].set_title("Generosity 20")
axs[5].boxplot(cleaned6yrsdf["Perceptions of corruption 20"])
axs[5].set_title("Perceptions of corruption 20")
plt.savefig('Results/boxplot_Perceptions of corruption 2020.png', bbox_inches='tight')
plt.show()

# %%
mexico = cleaned6yrsdf[cleaned6yrsdf["Country"]=="Mexico"]
mexico
# Out:
#    Country  Score 20  GDP per capita 20  Social Support 20  \
# 23  Mexico     6.465           1.024387           1.226333
#
#     Healthy life expectancy 20  Freedom to make life choices 20  \
# 23                    0.831601                         0.553893
#
#     Generosity 20  Perceptions of corruption 20  Score 19  GDP per capita 19  \
# 23       0.083094                      0.083134     6.595               1.07
#
#     ...  Generosity 16  Perceptions of corruption 16  Score 15  \
# 23  ...        0.11735                       0.18355     7.187
#
#     GDP per capita 15  Social Support 15  Healthy life expectancy 15  \
# 23            1.02054            0.91451                     0.81444
#
#     Freedom to make life choices 15  Generosity 15  \
# 23                          0.48181        0.14074
#
#     Perceptions of corruption 15  New Score
# 23                       0.21312   0.923479
#
# [1 rows x 44 columns]
