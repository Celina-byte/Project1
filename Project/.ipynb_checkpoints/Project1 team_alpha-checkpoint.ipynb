# %%
import pandas as pd
# !pip install openpyxl
import matplotlib.pyplot as plt
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Load file
datafile20 = "Resources/2020.csv"
datafile19 = "Resources/2019.csv"
datafile18 = "Resources/2018.csv"

# Read 202 File and store into Pandas data frame
yr20df = pd.read_csv(datafile20)
yr19df = pd.read_csv(datafile19)
yr18df = pd.read_csv(datafile18)

# %%
yr20df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
cleanedyr20df = yr20df[["Country name","Ladder score","Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Explained by: Generosity","Explained by: Perceptions of corruption"]]
cleanedyr20df = cleanedyr20df.rename(columns={"Country name":"Country",
                      "Ladder score":"Score 20",
                      "Explained by: Log GDP per capita":"GDP per capita 20",
                      "Explained by: Social support":"Social Support 20",
                    "Explained by: Healthy life expectancy":"Healthy life expectancy 20",
                    "Explained by: Freedom to make life choices":"Freedom to make life choices 20",
                    "Explained by: Generosity":"Generosity 20",
                    "Explained by: Perceptions of corruption":"Perceptions of corruption 20"
                     })
cleanedyr20df.shape
# Out:
# (153, 8)

# %%
yr19df = yr19df.rename(columns={"Country or region":"Country"})

# %%
cleanedyr20and19df = pd.merge(cleanedyr20df,yr19df,how='left',on ='Country')
cleanedyr20and19df = cleanedyr20and19df.rename(columns={
                      "Score":"Score 19",
                      "GDP per capita":"GDP per capita 19",
                      "Social support":"Social Support 19",
                    "Healthy life expectancy":"Healthy life expectancy 19",
                    "Freedom to make life choices":"Freedom to make life choices 19",
                    "Generosity":"Generosity 19",
                    "Perceptions of corruption":"Perceptions of corruption 19"
                     })
cleanedyr20and19df
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
yr18df = yr18df.rename(columns={"Country or region":"Country"})

# %%
cleaned3yrsdf = pd.merge(cleanedyr20and19df,yr18df,how='left',on ='Country')
cleaned3yrsdf
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 0                     Finland    7.8087           1.285190           1.499526
# 1                     Denmark    7.6456           1.326949           1.503449
# 2                 Switzerland    7.5599           1.390774           1.472403
# 3                     Iceland    7.5045           1.326502           1.547567
# 4                      Norway    7.4880           1.424207           1.495173
# ..                        ...       ...                ...                ...
# 148  Central African Republic    3.4759           0.041072           0.000000
# 149                    Rwanda    3.3123           0.343243           0.522876
# 150                  Zimbabwe    3.2992           0.425564           1.047835
# 151               South Sudan    2.8166           0.289083           0.553279
# 152               Afghanistan    2.5669           0.300706           0.356434
#
# ...

# %%
cleaned3yrsdf = cleaned3yrsdf.rename(columns={
                      "Score":"Score 18",
                      "GDP per capita":"GDP per capita 18",
                      "Social support":"Social Support 18",
                    "Healthy life expectancy":"Healthy life expectancy 18",
                    "Freedom to make life choices":"Freedom to make life choices 18",
                    "Generosity":"Generosity 18",
                    "Perceptions of corruption":"Perceptions of corruption 18"
                     })
del cleaned3yrsdf["Overall rank_x"]
del cleaned3yrsdf["Overall rank_y"]

# %%
cleaned3yrsdf.tail(20)
# Out:
#                       Country  Score 20  GDP per capita 20  Social Support 20  \
# 133                   Comoros    4.2886           0.415621           0.723233
# 134                      Togo    4.1872           0.268116           0.547623
# 135                  Ethiopia    4.1862           0.315126           1.001103
# 136                Madagascar    4.1656           0.244553           0.823694
# 137                     Egypt    4.1514           0.875229           0.982540
# 138              Sierra Leone    3.9264           0.240560           0.747985
# 139                   Burundi    3.7753           0.000000           0.403575
# 140                    Zambia    3.7594           0.536834           0.896037
# 141                     Haiti    3.7208           0.284734           0.646671
# 142                   Lesotho    3.6528           0.454939           1.088940
# 143                     India    3.5733           0.730576           0.644199
# ...

# %%
cleaned3yrsdf.to_excel("2018-2020 happiness.xlsx")

# %%
cleaned3yrsdf.dropna(inplace = True)
cleaned3yrsdf.count()
# Out:
# Country                            143
# Score 20                           143
# GDP per capita 20                  143
# Social Support 20                  143
# Healthy life expectancy 20         143
# Freedom to make life choices 20    143
# Generosity 20                      143
# Perceptions of corruption 20       143
# Score 19                           143
# GDP per capita 19                  143
# Social Support 19                  143
# Healthy life expectancy 19         143
# Freedom to make life choices 19    143
# Generosity 19                      143
# Perceptions of corruption 19       143
# Score 18                           143
# GDP per capita 18                  143
# Social Support 18                  143
# Healthy life expectancy 18         143
# Freedom to make life choices 18    143
# Generosity 18                      143
# Perceptions of corruption 18       143
# dtype: int64

# %%
cleaned3yrsdf.to_excel("2018-2020 happiness - cleaned.xlsx")

# %%
mean20=cleaned3yrsdf["Score 20"].mean()
mean20
# Out:
# 5.477041953097903

# %%
cleaned3yrsdf['New Score']=cleaned3yrsdf["Score 20"]-mean20

# %%
cleaned3yrsdf.head()
# Out:
#        Country  Score 20  GDP per capita 20  Social Support 20  \
# 0      Finland    7.8087           1.285190           1.499526
# 1      Denmark    7.6456           1.326949           1.503449
# 2  Switzerland    7.5599           1.390774           1.472403
# 3      Iceland    7.5045           1.326502           1.547567
# 4       Norway    7.4880           1.424207           1.495173
#
#    Healthy life expectancy 20  Freedom to make life choices 20  Generosity 20  \
# 0                    0.961271                         0.662317       0.159670
# 1                    0.979333                         0.665040       0.242793
# 2                    1.040533                         0.628954       0.269056
# 3                    1.000843                         0.661981       0.362330
# 4                    1.008072                         0.670201       0.287985
#
#    Perceptions of corruption 20  Score 19  GDP per capita 19  ...  \
# ...

# %%
plt.figure(figsize=(30,3))
plt.bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
plt.xticks(rotation='vertical')
plt.title('Happiest Countries')
plt.xlabel('Countries')
plt.ylabel('Happiness Score')
plt.show()

# %%
plt.figure(figsize=(30,3))
plt.bar(cleaned3yrsdf["Country"],cleaned3yrsdf["GDP per capita 20"])
plt.xticks(rotation='vertical')
plt.title('GDP')
plt.xlabel('Countries')
plt.ylabel('GDP')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["GDP per capita 20"])
axs[1].set_title('GDP per capita 2020')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(cleaned3yrsdf["GDP per capita 20"], cleaned3yrsdf["Score 20"], color="red")
plt.title("GDP per capita vs. Happiness index 2020")
plt.xlabel('GDP per capita 20')
plt.ylabel('Happiest Index 20')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["Social Support 20"])
axs[1].set_title('Social Support 2020')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(cleaned3yrsdf["Social Support 20"], cleaned3yrsdf["Score 20"], color="red")
plt.title("Social Support vs. Happiness index 2020")
plt.xlabel('Social Support 20')
plt.ylabel('Happiest Index 20')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["Healthy life expectancy 20"])
axs[1].set_title('Healthy Life Expectancy 2020')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(cleaned3yrsdf["Healthy life expectancy 20"], cleaned3yrsdf["Score 20"], color="red")
plt.title("Healthy Life Expectancy vs. Happiness index 2020")
plt.xlabel('Healthy Life Expectancy 20')
plt.ylabel('Happiest Index 20')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["Freedom to make life choices 20"])
axs[1].set_title('Freedom To Make Life Choices 20 2020')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(cleaned3yrsdf["Freedom to make life choices 20"], cleaned3yrsdf["Score 20"], color="red")
plt.title("Freedom To Make Life Choices vs. Happiness index 2020")
plt.xlabel('Freedom To Make Life Choices 20')
plt.ylabel('Happiest Index 20')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["Generosity 20"])
axs[1].set_title('Generosity 2020')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(cleaned3yrsdf["Generosity 20"], cleaned3yrsdf["Score 20"], color="red")
plt.title("Generosity vs. Happiness index 2020")
plt.xlabel('Generosity 20')
plt.ylabel('Happiest Index 20')
plt.show()

# %%
fig, axs = plt.subplots(2,figsize=(25,5),sharex=True)
#fig.suptitle('')
axs[0].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["New Score"])
axs[0].set_title('Happiness Index 2020')
axs[1].bar(cleaned3yrsdf["Country"],cleaned3yrsdf["Perceptions of corruption 20"])
axs[1].set_title('Perceptions of corruption 2020')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(cleaned3yrsdf["Perceptions of corruption 20"], cleaned3yrsdf["Score 20"], color="red")
plt.title("Perceptions of Corruption vs. Happiness index 2020")
plt.xlabel('Perceptions of Corruption 20')
plt.ylabel('Happiest Index 20')
plt.show()

# %%
fig, axs = plt.subplots(3,sharey=True,figsize=(5,13))
axs[0].scatter(cleaned3yrsdf["Social Support 20"], cleaned3yrsdf["Score 20"])
axs[0].set_title('Social Support 2020')
axs[1].scatter(cleaned3yrsdf["Social Support 19"], cleaned3yrsdf["Score 19"])
axs[1].set_title('Social Support 2019')
axs[2].scatter(cleaned3yrsdf["Social Support 18"], cleaned3yrsdf["Score 18"])
axs[2].set_title('Social Support 2018')
plt.show()

# %%
fig, axs = plt.subplots(3,sharey=True,figsize=(5,13))
axs[0].scatter(cleaned3yrsdf["GDP per capita 20"], cleaned3yrsdf["Score 20"])
axs[0].set_title('GDP 2020')
axs[1].scatter(cleaned3yrsdf["GDP per capita 19"], cleaned3yrsdf["Score 19"])
axs[1].set_title('GDP 2019')
axs[2].scatter(cleaned3yrsdf["GDP per capita 18"], cleaned3yrsdf["Score 18"])
axs[2].set_title('GDP 2018')
plt.show()

# %%
fig, axs = plt.subplots(3,sharey=True,figsize=(5,13))
axs[0].scatter(cleaned3yrsdf["Healthy life expectancy 20"], cleaned3yrsdf["Score 20"])
axs[0].set_title('Healthy life expectancy 2020')
axs[1].scatter(cleaned3yrsdf["Healthy life expectancy 19"], cleaned3yrsdf["Score 19"])
axs[1].set_title('Healthy life expectancy 2019')
axs[2].scatter(cleaned3yrsdf["Healthy life expectancy 18"], cleaned3yrsdf["Score 18"])
axs[2].set_title('Healthy life expectancy 2018')
plt.show()

# %%
fig, axs = plt.subplots(3,sharey=True,figsize=(5,13))
axs[0].scatter(cleaned3yrsdf["Freedom to make life choices 20"], cleaned3yrsdf["Score 20"])
axs[0].set_title('Freedom to make life choices 2020')
axs[1].scatter(cleaned3yrsdf["Freedom to make life choices 19"], cleaned3yrsdf["Score 19"])
axs[1].set_title('Freedom to make life choices 2019')
axs[2].scatter(cleaned3yrsdf["Freedom to make life choices 18"], cleaned3yrsdf["Score 18"])
axs[2].set_title('Freedom to make life choices 2018')
plt.show()

# %%
fig, axs = plt.subplots(3,sharey=True,figsize=(5,13))
axs[0].scatter(cleaned3yrsdf["Generosity 20"], cleaned3yrsdf["Score 20"])
axs[0].set_title('Generosity 2020')
axs[1].scatter(cleaned3yrsdf["Generosity 19"], cleaned3yrsdf["Score 19"])
axs[1].set_title('Generosity 2019')
axs[2].scatter(cleaned3yrsdf["Generosity 18"], cleaned3yrsdf["Score 18"])
axs[2].set_title('Generosity 2018')
plt.show()

# %%
fig, axs = plt.subplots(3,sharey=True,figsize=(5,13))
axs[0].scatter(cleaned3yrsdf["Perceptions of corruption 20"], cleaned3yrsdf["Score 20"])
axs[0].set_title('Perceptions of corruption 2020')
axs[1].scatter(cleaned3yrsdf["Perceptions of corruption 19"], cleaned3yrsdf["Score 19"])
axs[1].set_title('Perceptions of corruption 2019')
axs[2].scatter(cleaned3yrsdf["Perceptions of corruption 18"], cleaned3yrsdf["Score 18"])
axs[2].set_title('Perceptions of corruption 2018')
plt.show()

# %%
fig, axs = plt.subplots(1,6,sharey=True,figsize=(20
                                                ,5))
fig.suptitle('Box plots for each variable')
axs[0].boxplot(cleaned3yrsdf["GDP per capita 20"])
axs[0].set_title("GDP per capita 20")
axs[1].boxplot(cleaned3yrsdf["Social Support 20"])
axs[1].set_title("Social Support 20")
axs[2].boxplot(cleaned3yrsdf["Healthy life expectancy 20"])
axs[2].set_title("Healthy life expectancy 20")
axs[3].boxplot(cleaned3yrsdf["Freedom to make life choices 20"])
axs[3].set_title("Freedom to make life choices 20")
axs[4].boxplot(cleaned3yrsdf["Generosity 20"])
axs[4].set_title("Generosity 20")
axs[5].boxplot(cleaned3yrsdf["Perceptions of corruption 20"])
axs[5].set_title("Perceptions of corruption 20")
plt.show()
